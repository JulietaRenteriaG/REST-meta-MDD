# %% [markdown]
# # 02 - Feature Extraction: Functional Connectivity
#
# Extracts pairwise Pearson correlations between the **264 ROIs** defined by Power et al. (2011)
# from DPARSF-preprocessed ROISignals `.mat` files.
#
# **Input:** ROISignals_FunImgARglobalCWF/*.mat
# **Output:** data/processed/connectivity_power264.csv
#
# ### Power-264 column mapping inside ROISignals (DPARSF v4.3+)
# | Block | Columns (1-indexed) | Python slice |
# |---|---|---|
# | AAL 116 ROIs | 1 – 116 | [:, 0:116] |
# | Harvard-Oxford cortical | 117 – 212 | [:, 116:212] |
# | Power-264 ROIs | 1570 – 1833 | [:, 1569:1833] |
# | Schaefer-400 | 1834 – 2233 | [:, 1833:2233] |

# %%
import os
import re
import glob
import logging
import numpy as np
import pandas as pd
from scipy.io import loadmat

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s  %(levelname)-8s  %(message)s',
    datefmt='%H:%M:%S'
)
logger = logging.getLogger(__name__)

# %%
os.environ["RAW_ROI_DIR_PATH"] = "/mnt/c/Users/julsr/Desktop/REST-meta-MDD/REST-meta-MDD-Phase1-Sharing/Results/ROISignals_FunImgARglobalCWF"

PATH_ROI_DIR = os.getenv("RAW_ROI_DIR_PATH")
OUTPUT_CSV = "data/connectivity_power264.csv"

POWER_START    = 1569
POWER_END      = 1833
N_POWER        = POWER_END - POWER_START 
N_FEATURES     = N_POWER * (N_POWER - 1) // 2 
MIN_TIMEPOINTS = 30

print(f"Power-264 ROIs : {N_POWER}")
print(f"FC features    : {N_FEATURES:,}")
print(repr(PATH_ROI_DIR))
print("¿Directorio existe?", os.path.isdir(PATH_ROI_DIR))
# Out:
# Power-264 ROIs : 264
# FC features    : 34,716
# '/mnt/c/Users/julsr/Desktop/REST-meta-MDD/REST-meta-MDD-Phase1-Sharing/Results/ROISignals_FunImgARglobalCWF'
# ¿Directorio existe? True

# %%
def load_roi_signals(mat_path: str) -> np.ndarray:
    data = loadmat(mat_path)

    if "ROISignals" not in data:
        raise KeyError(f"'ROISignals' key not found in {mat_path}")

    roi = data["ROISignals"]

    if roi.ndim != 2:
        raise ValueError(f"ROISignals is not 2D (shape {roi.shape})")
    if roi.shape[1] < POWER_END:
        raise ValueError(f"Only {roi.shape[1]} columns - need > {POWER_END}")
    if roi.shape[0] < MIN_TIMEPOINTS:
        raise ValueError(f"Only {roi.shape[0]} timepoints - need > {MIN_TIMEPOINTS}")

    return roi


def compute_fc_vector(roi_signals: np.ndarray) -> np.ndarray:
    """Return upper-triangle FC vector (34,716,) for Power-264 ROIs."""
    power = roi_signals[:, POWER_START:POWER_END]  # (T, 264)
    corr  = np.corrcoef(power.T)                   # (264, 264)

    if np.isnan(corr).any():
        n_nan = int(np.isnan(corr).sum())
        logger.warning("Replaced %d NaN values (zero-variance ROI)", n_nan)
        corr = np.nan_to_num(corr, nan=0.0)

    tri = np.triu_indices(N_POWER, k=1)
    return corr[tri]


def subject_id_from_path(mat_path: str) -> str:
    fname = os.path.basename(mat_path)
    m = re.search(r"(S\d+-\d+-\d{4})", fname)
    return m.group(1) if m else os.path.splitext(fname)[0]

# %%
mat_files = sorted(glob.glob(os.path.join(PATH_ROI_DIR, "*.mat")))
logger.info("Found %d .mat files", len(mat_files))

rows, subject_ids, errors = [], [], []

for i, fp in enumerate(mat_files, start=1):
    try:
        roi = load_roi_signals(fp)
        vec = compute_fc_vector(roi)
        rows.append(vec)
        subject_ids.append(subject_id_from_path(fp))
    except Exception as exc:
        errors.append({"file": os.path.basename(fp), "reason": str(exc)})
        logger.warning("Skipped %s — %s", os.path.basename(fp), exc)

    if i == 1 or i % 200 == 0 or i == len(mat_files):
        logger.info("  Processed %d / %d", i, len(mat_files))

print(f"\nValid subjects : {len(subject_ids)}")
print(f"Failed files   : {len(errors)}")
# Out:
# 13:27:32  INFO      Found 2428 .mat files
# 13:27:32  INFO        Processed 1 / 2428
# /home/juls/REST-meta-MDD/.venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/juls/REST-meta-MDD/.venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# 13:27:33  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:27:33  WARNING   Replaced 3647 NaN values (zero-variance ROI)
# 13:27:33  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:27:37  WARNING   Replaced 4671 NaN values (zero-variance ROI)
# 13:27:38  WARNING   Replaced 3132 NaN values (zero-variance ROI)
# 13:27:45  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:27:47  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:27:48  INFO        Processed 200 / 2428
# 13:27:52  WARNING   Replaced 2615 NaN values (zero-variance ROI)
# 13:27:53  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:27:55  WARNING   Replaced 5180 NaN values (zero-variance ROI)
# 13:27:56  WARNING   Replaced 5180 NaN values (zero-variance ROI)
# 13:28:01  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:28:01  WARNING   Replaced 2096 NaN values (zero-variance ROI)
# 13:28:05  WARNING   Replaced 2615 NaN values (zero-variance ROI)
# 13:28:03  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:28:05  INFO        Processed 400 / 2428
# 13:28:12  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:28:12  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:28:12  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:28:13  WARNING   Replaced 11132 NaN values (zero-variance ROI)
# 13:28:13  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:28:14  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:28:15  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:28:20  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:28:23  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:28:24  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:28:25  INFO        Processed 600 / 2428
# 13:28:28  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:28:30  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:28:30  WARNING   Replaced 2615 NaN values (zero-variance ROI)
# 13:28:30  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:28:31  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:28:31  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:28:35  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:28:35  WARNING   Replaced 4160 NaN values (zero-variance ROI)
# 13:28:35  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:28:39  WARNING   Skipped ROISignals_S19-1-0001.mat — Only 1568 columns — need ≥ 1833
# 13:28:39  WARNING   Skipped ROISignals_S19-1-0002.mat — Only 1568 columns — need ≥ 1833
# 13:28:39  WARNING   Skipped ROISignals_S19-1-0003.mat — Only 1568 columns — need ≥ 1833
# 13:28:39  WARNING   Skipped ROISignals_S19-1-0004.mat — Only 1568 columns — need ≥ 1833
# 13:28:39  WARNING   Skipped ROISignals_S19-1-0005.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0006.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0007.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0008.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0009.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0010.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0011.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0012.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0013.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0014.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0015.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0016.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0017.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0018.mat — Only 1568 columns — need ≥ 1833
# 13:28:40  WARNING   Skipped ROISignals_S19-1-0019.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0020.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0021.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0022.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0023.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0024.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0025.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0026.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0027.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0028.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0029.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0030.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0031.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0032.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0033.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0034.mat — Only 1568 columns — need ≥ 1833
# 13:28:41  WARNING   Skipped ROISignals_S19-1-0035.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0036.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0037.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0038.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  INFO        Processed 800 / 2428
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0039.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0040.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0041.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0042.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0043.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0044.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0045.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0046.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0047.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0048.mat — Only 1568 columns — need ≥ 1833
# 13:28:42  WARNING   Skipped ROISignals_S19-1-0049.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-1-0050.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-1-0051.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0001.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0002.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0003.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0004.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0005.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0006.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0007.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0008.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0009.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0010.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0011.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0012.mat — Only 1568 columns — need ≥ 1833
# 13:28:43  WARNING   Skipped ROISignals_S19-2-0013.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0014.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0015.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0016.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0017.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0018.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0019.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0020.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0021.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0022.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0023.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0024.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0025.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0026.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0027.mat — Only 1568 columns — need ≥ 1833
# 13:28:44  WARNING   Skipped ROISignals_S19-2-0028.mat — Only 1568 columns — need ≥ 1833
# 13:28:45  WARNING   Skipped ROISignals_S19-2-0029.mat — Only 1568 columns — need ≥ 1833
# 13:28:45  WARNING   Skipped ROISignals_S19-2-0030.mat — Only 1568 columns — need ≥ 1833
# 13:28:45  WARNING   Skipped ROISignals_S19-2-0031.mat — Only 1568 columns — need ≥ 1833
# 13:28:45  WARNING   Skipped ROISignals_S19-2-0032.mat — Only 1568 columns — need ≥ 1833
# 13:28:45  WARNING   Skipped ROISignals_S19-2-0033.mat — Only 1568 columns — need ≥ 1833
# 13:28:45  WARNING   Skipped ROISignals_S19-2-0034.mat — Only 1568 columns — need ≥ 1833
# 13:28:45  WARNING   Skipped ROISignals_S19-2-0035.mat — Only 1568 columns — need ≥ 1833
# 13:28:45  WARNING   Skipped ROISignals_S19-2-0036.mat — Only 1568 columns — need ≥ 1833
# 13:28:47  WARNING   Replaced 3132 NaN values (zero-variance ROI)
# 13:28:49  WARNING   Replaced 53567 NaN values (zero-variance ROI)
# 13:28:50  WARNING   Replaced 44732 NaN values (zero-variance ROI)
# 13:28:54  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:28:55  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:28:57  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:29:00  INFO        Processed 1000 / 2428
# 13:29:01  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:29:19  INFO        Processed 1200 / 2428
# 13:29:22  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:29:23  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:29:25  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:29:28  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:29:38  INFO        Processed 1400 / 2428
# 13:29:46  WARNING   Replaced 51471 NaN values (zero-variance ROI)
# 13:29:59  INFO        Processed 1600 / 2428
# 13:30:00  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:30:16  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:30:17  INFO        Processed 1800 / 2428
# 13:30:35  WARNING   Replaced 2615 NaN values (zero-variance ROI)
# 13:30:36  INFO        Processed 2000 / 2428
# 13:30:37  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:38  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:30:38  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:38  WARNING   Replaced 3647 NaN values (zero-variance ROI)
# 13:30:38  WARNING   Replaced 2615 NaN values (zero-variance ROI)
# 13:30:38  WARNING   Replaced 3132 NaN values (zero-variance ROI)
# 13:30:38  WARNING   Replaced 2096 NaN values (zero-variance ROI)
# 13:30:38  WARNING   Replaced 2615 NaN values (zero-variance ROI)
# 13:30:38  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:38  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:30:38  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:38  WARNING   Replaced 2615 NaN values (zero-variance ROI)
# 13:30:38  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:39  WARNING   Replaced 2096 NaN values (zero-variance ROI)
# 13:30:39  WARNING   Replaced 3132 NaN values (zero-variance ROI)
# 13:30:40  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:42  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:42  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:30:43  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:30:43  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:30:43  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:30:44  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:46  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:30:46  WARNING   Replaced 3647 NaN values (zero-variance ROI)
# 13:30:46  WARNING   Replaced 6192 NaN values (zero-variance ROI)
# 13:30:47  WARNING   Replaced 2096 NaN values (zero-variance ROI)
# 13:30:47  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:47  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:48  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:50  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:30:50  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:50  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:30:51  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:51  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:51  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:30:51  INFO        Processed 2200 / 2428
# 13:30:52  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:52  WARNING   Replaced 4160 NaN values (zero-variance ROI)
# 13:30:52  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:30:53  WARNING   Replaced 4160 NaN values (zero-variance ROI)
# 13:30:54  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:30:54  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:54  WARNING   Replaced 4160 NaN values (zero-variance ROI)
# 13:30:54  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:30:54  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:30:55  WARNING   Replaced 3647 NaN values (zero-variance ROI)
# 13:30:55  WARNING   Replaced 2096 NaN values (zero-variance ROI)
# 13:30:55  WARNING   Replaced 1575 NaN values (zero-variance ROI)
# 13:30:55  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:56  WARNING   Replaced 2096 NaN values (zero-variance ROI)
# 13:30:56  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:30:56  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:30:57  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:30:57  WARNING   Replaced 34352 NaN values (zero-variance ROI)
# 13:30:58  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:31:00  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:31:00  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:31:00  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:31:01  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:31:01  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:31:01  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:31:02  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:31:02  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:31:02  WARNING   Replaced 1052 NaN values (zero-variance ROI)
# 13:31:03  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:31:03  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:31:03  WARNING   Replaced 4160 NaN values (zero-variance ROI)
# 13:31:09  WARNING   Replaced 527 NaN values (zero-variance ROI)
# 13:31:09  INFO        Processed 2400 / 2428
# 13:31:11  INFO        Processed 2428 / 2428
# Valid subjects : 2341
# Failed files   : 87

# %%
if errors:
    errors_df = pd.DataFrame(errors)
    print(errors_df.to_string(index=False))
else:
    print("No errors found.")
# Out:
#                      file                          reason
# ROISignals_S19-1-0001.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0002.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0003.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0004.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0005.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0006.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0007.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0008.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0009.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0010.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0011.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0012.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0013.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0014.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0015.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0016.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0017.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0018.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0019.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0020.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0021.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0022.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0023.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0024.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0025.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0026.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0027.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0028.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0029.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0030.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0031.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0032.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0033.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0034.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0035.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0036.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0037.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0038.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0039.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0040.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0041.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0042.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0043.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0044.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0045.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0046.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0047.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0048.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0049.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0050.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-1-0051.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0001.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0002.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0003.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0004.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0005.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0006.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0007.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0008.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0009.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0010.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0011.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0012.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0013.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0014.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0015.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0016.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0017.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0018.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0019.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0020.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0021.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0022.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0023.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0024.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0025.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0026.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0027.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0028.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0029.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0030.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0031.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0032.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0033.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0034.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0035.mat Only 1568 columns — need ≥ 1833
# ROISignals_S19-2-0036.mat Only 1568 columns — need ≥ 1833

# %%
feature_cols = [f"fc_{i}" for i in range(N_FEATURES)]

connectivity_df = pd.DataFrame(np.vstack(rows), columns=feature_cols)
connectivity_df.insert(0, "subject_id", subject_ids)

print("DataFrame shape:", connectivity_df.shape)

os.makedirs(os.path.dirname(OUTPUT_CSV), exist_ok=True)
connectivity_df.to_csv(OUTPUT_CSV, index=False)
print(f"Saved to: {OUTPUT_CSV}")
# Out:
# DataFrame shape: (2341, 34717)
# Saved to: data/connectivity_power264.csv

# %% [markdown]
# ### Quick sanity check

# %%
df_check = pd.read_csv(OUTPUT_CSV, nrows=5)
print(df_check.iloc[:, :6])   # subject_id + first 5 FC features
print("\nValue range:", connectivity_df.iloc[:, 1:].min().min().round(4),
      "to", connectivity_df.iloc[:, 1:].max().max().round(4))
# Out:
#   subject_id      fc_0      fc_1      fc_2      fc_3      fc_4
# 0  S1-1-0001  0.202817  0.152647 -0.157986  0.089926  0.177332
# 1  S1-1-0002  0.670407  0.168486 -0.237733  0.153526 -0.145674
# 2  S1-1-0003  0.220351  0.158293  0.079606  0.437309  0.169528
# 3  S1-1-0004  0.379851  0.098425 -0.011917 -0.206627 -0.194602
# 4  S1-1-0005  0.545908  0.069256 -0.010697 -0.090901  0.427948
#
# Value range: -0.9794 to 0.9868
